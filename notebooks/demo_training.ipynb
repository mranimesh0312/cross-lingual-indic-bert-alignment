# %% [markdown]
# # Demo Training
#
# Minimal walkthrough for MLM + alignment training and Hindi WikiANN NER fine-tuning.

# %%
from pathlib import Path
import sys
sys.path.append(str(Path.cwd().parents[0] if Path.cwd().name == 'notebooks' else Path.cwd()))
from src.config import load_config
config = load_config('config.yaml')
config.base_model_name, config.languages[:3]

# %%
# Smoke-test training. Full runs should use larger corpora and GPU.
# from src.mlm_training import train_mlm_alignment
# train_mlm_alignment(config)

# %%
# NER fine-tuning demo
# from src.ner_finetuning import train_ner
# train_ner(config, language='hi')
